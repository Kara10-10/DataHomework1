# %% [markdown]
# # SQLite
# ## Maximum 50 points out of 100 (total exam)

# %% [markdown]
# ## You are expected to use a single query for each of the exercise below:

# %% [markdown]
# 1. Find all records where the total_bill exceeds $50. (2 points)
# 2. Calculate the average tip given. (2 points)
# 3. Find the maximum total_bill paid. (2 points)
# 4. Count how many people were served on each day. (4 points)
# 5. Calculate the average total_bill grouped by size. (4 points)
# 6. Find the total tip amount for smokers vs. non-smokers. (4 points)
# 7. Determine the average tip percentage (tip/total_bill) for each day. (4 points)
# 8. List all total_bill values with the corresponding day and time. (4 points)
# 9. Find the total number of observations for each gender. (4 points)
# 10. Retrieve all tips given during Dinner on Saturday. (4 points)
# 11. Find the largest total_bill for each gender. (4 points)
# 12. Find the average tip for parties of size greater than 4. (4 points)
# 13. Find all records from where the day is either Friday or Saturday, and the time is Lunch or Dinner. (4 points)
# 14. List all records where the tip percentage is higher than 20%. (4 points)

# %% [markdown]
# ## Bonus question (10 points)
#
#
# 15. Use a subquery (query inside query) to find the record with the second highest tip. (you need to use a single query)

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("tips.db")
cur = conn.cursor()

# %%
query = "SELECT name FROM sqlite_master WHERE type = 'table'"
cur.execute(query)
cur.fetchall()
# Out:
# [('Observation',), ('Sex',), ('Smoker',), ('Day',), ('Time',)]

# %% [markdown]
# 1. Find all records where the total_bill exceeds $50. (2 points

# %%
query = "SELECT * FROM Observation;"
pd.read_sql(query, conn)
# Out:
#      total_bill   tip  size  sex_id  smoker_id  day_id  time_id
# 0         16.99  1.01     2       1          1       3        1
# 1         10.34  1.66     3       0          1       3        1
# 2         21.01  3.50     3       0          1       3        1
# 3         23.68  3.31     2       0          1       3        1
# 4         24.59  3.61     4       1          1       3        1
# ..          ...   ...   ...     ...        ...     ...      ...
# 239       29.03  5.92     3       0          1       2        1
# 240       27.18  2.00     2       1          0       2        1
# 241       22.67  2.00     2       0          0       2        1
# 242       17.82  1.75     2       0          1       2        1
# 243       18.78  3.00     2       1          1       0        1
#
# [244 rows x 7 columns]

# %%
query = """
SELECT * FROM Observation
WHERE Observation.total_bill > 50
;"""
pd.read_sql(query, conn)
# Out:
#    total_bill   tip  size  sex_id  smoker_id  day_id  time_id
# 0       50.81  10.0     3       0          0       2        1

# %% [markdown]
# 2. Calculate the average tip given. (2 points)

# %%
query = """
SELECT AVG(Observation.tip) as Average_tip FROM Observation
;"""
pd.read_sql(query, conn)
# Out:
#    Average_tip
# 0     2.998279

# %% [markdown]
# 3. Find the maximum total_bill paid. (2 points)

# %%
query = """
SELECT MAX(Observation.total_bill) as Maximum_bill FROM Observation
;"""
pd.read_sql(query, conn)
# Out:
#    Maximum_bill
# 0         50.81

# %% [markdown]
# 4. Count how many people were served on each day. (4 points)

# %%
query = "SELECT * FROM Day;"
pd.read_sql(query, conn)
# Out:
#    day_id   day
# 0       0  Thur
# 1       1   Fri
# 2       2   Sat
# 3       3   Sun

# %%
query = """
SELECT SUM(Observation.size) as customers, Day.day FROM Observation
JOIN Day ON Day.day_id=Observation.day_id
GROUP BY Day.day
;"""
pd.read_sql(query, conn)
# Out:
#    customers   day
# 0         40   Fri
# 1        219   Sat
# 2        216   Sun
# 3        152  Thur

# %% [markdown]
# 5. Calculate the average total_bill grouped by size

# %%
query = """
SELECT AVG(Observation.total_bill) as Average_bill, Observation.size FROM Observation
GROUP BY  Observation.size
;"""
pd.read_sql(query, conn)
# Out:
#    Average_bill  size
# 0      7.242500     1
# 1     16.448013     2
# 2     23.277632     3
# 3     28.613514     4
# 4     30.068000     5
# 5     34.830000     6

# %% [markdown]
# 6. Find the total tip amount for smokers vs. non-smokers.

# %%
query = "SELECT * FROM Smoker;"
pd.read_sql(query, conn)
# Out:
#    smoker_id smoker
# 0          0    Yes
# 1          1     No

# %%
query = """
SELECT SUM(Observation.tip) as Total_tip, Smoker.smoker FROM Observation
JOIN Smoker ON Smoker.smoker_id=Observation.smoker_id
GROUP BY Smoker.smoker
;"""
pd.read_sql(query, conn)
# Out:
#    Total_tip smoker
# 0     451.77     No
# 1     279.81    Yes

# %% [markdown]
# 7. Determine the average tip percentage (tip/total_bill) for each day. (4 points)

# %%
query = """
SELECT (Observation.tip)*100/(Observation.total_bill) as Average_tip_perc, Day.day FROM Observation
JOIN Day ON Day.day_id=Observation.day_id
GROUP BY  Day.day
;"""
pd.read_sql(query, conn)
# Out:
#    Average_tip_perc   day
# 0         10.355540   Fri
# 1         16.222760   Sat
# 2          5.944673   Sun
# 3         14.705882  Thur

# %%
query = """
SELECT AVG((Observation.tip)*100/(Observation.total_bill)) as Average_tip_perc, Day.day FROM Observation
JOIN Day ON Day.day_id=Observation.day_id
GROUP BY  Day.day
;"""
pd.read_sql(query, conn)
# Out:
#    Average_tip_perc   day
# 0         16.991303   Fri
# 1         15.315172   Sat
# 2         16.689729   Sun
# 3         16.127563  Thur

# %% [markdown]
# 8. List all total_bill values with the corresponding day and time. (4 points)

# %%
query = "SELECT * FROM Time;"
pd.read_sql(query, conn)
# Out:
#    time_id    time
# 0        0   Lunch
# 1        1  Dinner

# %%
query = """
SELECT Observation.total_bill as Totall_bill, Day.day, Time.time FROM Observation
JOIN Day ON Day.day_id=Observation.day_id
JOIN Time ON Time.time_id=Observation.time_id
GROUP BY Observation.total_bill
;"""
pd.read_sql(query, conn)
# Out:
#      Totall_bill   day    time
# 0           3.07   Sat  Dinner
# 1           5.75   Fri  Dinner
# 2           7.25   Sat  Dinner
# 3           7.51  Thur   Lunch
# 4           7.56  Thur   Lunch
# ..           ...   ...     ...
# 224        45.35   Sun  Dinner
# 225        48.17   Sun  Dinner
# 226        48.27   Sat  Dinner
# 227        48.33   Sat  Dinner
# 228        50.81   Sat  Dinner
#
# [229 rows x 3 columns]

# %% [markdown]
# # **<font color='red'> There is no need to group by the records by total_bill. Minus 1 point </font>**

# %% [markdown]
# 9. Find the total number of observations for each gender. (4 points)

# %%
query = """
SELECT COUNT(Observation.sex_id) as Total_number, Sex.sex FROM Observation
JOIN Sex ON Sex.sex_id=Observation.sex_id
GROUP BY Sex.sex
;"""
pd.read_sql(query, conn)
# Out:
#    Total_number     sex
# 0            87  Female
# 1           157    Male

# %% [markdown]
# 10. Retrieve all tips given during Dinner on Saturday. (4 points)

# %%
query = "SELECT * FROM Time;"
pd.read_sql(query, conn)
# Out:
#    time_id    time
# 0        0   Lunch
# 1        1  Dinner

# %%
query = """
SELECT SUM(Observation.tip) as Tip, Time.time FROM Observation
JOIN Time ON Time.time_id=Observation.time_id
JOIN Day ON Day.day_id=Observation.day_id
WHERE Day.day = 'Sat' AND Time.time = 'Dinner'
;"""
pd.read_sql(query, conn)
# Out:
#      Tip    time
# 0  260.4  Dinner

# %% [markdown]
# # **<font color='red'> All the records satisfying the defined condition should be displayed. Minus 1 point </font>**

# %% [markdown]
# 11. Find the largest total_bill for each gender. (4 points)

# %%
query = """
SELECT MAX(Observation.total_bill) as Largest_bill, Sex.sex FROM Observation
JOIN Sex ON Sex.sex_id=Observation.sex_id
GROUP BY Sex.sex
;"""
pd.read_sql(query, conn)
# Out:
#    Largest_bill     sex
# 0         44.30  Female
# 1         50.81    Male

# %% [markdown]
# 12.Find the average tip for parties of size greater than 4. (4 points)

# %%
query = """
SELECT AVG(Observation.tip) as Av_tip FROM Observation
WHERE Observation.size > 4
;"""
pd.read_sql(query, conn)
# Out:
#    Av_tip
# 0    4.56

# %% [markdown]
# 13.Find all records from where the day is either Friday or Saturday, and the time is Lunch or Dinner. (4 points)

# %%
query = """
SELECT * FROM Observation
JOIN Day ON Day.day_id=Observation.day_id
JOIN Time ON Time.time_id=Observation.time_id
WHERE (Day.day = 'Sat' OR Day.day = 'Fri') AND (Time.time = 'Lunch' OR Time.time = 'Dinner')
;"""
pd.read_sql(query, conn)
# Out:
#      total_bill    tip  size  sex_id  smoker_id  day_id  time_id  day_id  day  \
# 0          5.75   1.00     2       1          0       1        1       1  Fri
# 1          8.58   1.92     1       0          0       1        0       1  Fri
# 2         10.09   2.00     2       1          0       1        0       1  Fri
# 3         11.35   2.50     2       1          0       1        1       1  Fri
# 4         12.03   1.50     2       0          0       1        1       1  Fri
# ..          ...    ...   ...     ...        ...     ...      ...     ...  ...
# 101       39.42   7.58     4       0          1       2        1       2  Sat
# 102       44.30   2.50     3       1          0       2        1       2  Sat
# 103       48.27   6.73     4       0          1       2        1       2  Sat
# 104       48.33   9.00     4       0          1       2        1       2  Sat
# 105       50.81  10.00     3       0          0       2        1       2  Sat
#
#      time_id    time
# 0          1  Dinner
# 1          0   Lunch
# 2          0   Lunch
# 3          1  Dinner
# 4          1  Dinner
# ..       ...     ...
# 101        1  Dinner
# 102        1  Dinner
# 103        1  Dinner
# 104        1  Dinner
# 105        1  Dinner
#
# [106 rows x 11 columns]

# %% [markdown]
# 14.List all records where the tip percentage is higher than 20%. (4 points)

# %%
query = """
SELECT * FROM Observation
WHERE (Observation.tip*100)/Observation.total_bill > 20
;"""
pd.read_sql(query, conn)
# Out:
#     total_bill   tip  size  sex_id  smoker_id  day_id  time_id
# 0         8.77  2.00     2       0          1       3        1
# 1        14.78  3.23     2       0          1       3        1
# 2        14.83  3.02     2       1          1       3        1
# 3        16.29  3.71     3       0          1       3        1
# 4        16.97  3.50     3       1          1       3        1
# 5        17.92  4.08     2       0          1       2        1
# 6        13.94  3.06     2       0          1       3        1
# 7        22.23  5.00     2       0          1       3        1
# 8        10.29  2.60     2       1          1       3        1
# 9        18.29  3.76     4       0          0       2        1
# 10        3.07  1.00     1       1          0       2        1
# 11       16.66  3.40     2       0          1       0        0
# 12       18.28  4.00     2       0          1       0        0
# 13       24.71  5.85     2       0          1       0        0
# 14       16.32  4.30     2       1          0       1        1
# 15       11.35  2.50     2       1          0       1        1
# 16       18.24  3.76     2       0          1       2        1
# 17       14.31  4.00     2       1          0       2        1
# 18       14.00  3.00     2       0          1       2        1
# 19       17.31  3.50     2       1          1       3        1
# 20       12.48  2.52     2       1          1       0        0
# 21       13.16  2.75     2       1          1       0        0
# 22       17.47  3.50     2       1          1       0        0
# 23        7.51  2.00     2       0          1       0        0
# 24        7.25  5.15     2       0          0       3        1
# 25       16.82  4.00     2       0          0       3        1
# 26        9.60  4.00     2       1          0       3        1
# 27       23.33  5.65     2       0          0       3        1
# 28       23.17  6.50     4       0          0       3        1
# 29       20.69  5.00     5       0          1       3        1
# 30       19.81  4.19     2       1          0       0        0
# 31       16.58  4.00     2       0          0       0        0
# 32       18.71  4.00     3       0          0       0        0
# 33       28.17  6.50     3       1          0       2        1
# 34       13.42  3.48     2       1          0       1        0
# 35        8.58  1.92     1       0          0       1        0
# 36       13.28  2.72     2       0          1       2        1
# 37       11.61  3.39     2       0          1       2        1
# 38       29.03  5.92     3       0          1       2        1

# %% [markdown]
# 15. Use a subquery (query inside query) to find the record with the second highest tip. (you need to use a single query

# %%
query = """
SELECT * FROM Observation
WHERE Observation.tip = (
    SELECT MAX(Observation.tip) FROM Observation
    WHERE Observation.tip < (
        SELECT MAX(Observation.tip) FROM Observation
    )
)
;"""
pd.read_sql(query, conn)
# Out:
#    total_bill  tip  size  sex_id  smoker_id  day_id  time_id
# 0       48.33  9.0     4       0          1       2        1
